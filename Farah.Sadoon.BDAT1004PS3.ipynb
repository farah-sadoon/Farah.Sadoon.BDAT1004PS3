# %% [markdown]
# # Problem Set 3
# BDAT 1004 - Data Programming
#
#
# Farah Sadoon 200574206

# %% [markdown]
# <h3><font color='#004b87'>Introduction </font></h3>
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 1 </font></h3>
#
# <h4><font>Occupations</font></h4>
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this address: https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
#
# Step 3. Assign it to a variable called users
#
# Step 4. Discover what is the mean age per occupation
#
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
#
# Step 6. For each occupation, calculate the minimum and maximum ages
#
# Step 7. For each combination of occupation and sex, calculate the mean age
#
# Step 8. For each occupation present the percentage of women and men

# %%
# Step 1. Import the necessary libraries
import numpy as np
import pandas as pd

# %%
# Step 2. Import the dataset from the specified address
# Step 3. Assign it to a variable called users

users = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep = '|', index_col = 0)
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
# Step 4. Discover what is the mean age per occupation
users.groupby(['occupation'])['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
users.groupby(['occupation'])['gender'].value_counts()
# Out:
# occupation     gender
# administrator  M          43
#                F          36
# artist         M          15
#                F          13
# doctor         M           7
# educator       M          69
#                F          26
# engineer       M          65
#                F           2
# entertainment  M          16
#                F           2
# executive      M          29
#                F           3
# healthcare     F          11
#                M           5
# homemaker      F           6
#                M           1
# lawyer         M          10
#                F           2
# librarian      F          29
#                M          22
# marketing      M          16
#                F          10
# none           M           5
#                F           4
# other          M          69
#                F          36
# programmer     M          60
#                F           6
# retired        M          13
#                F           1
# ...

# %%
# Step 6. For each occupation, calculate the minimum and maximum ages
min_age = users.groupby(['occupation'])['age'].min()
print("The minimum age for each occupation is:\n{} ".format(min_age.to_string(header = False)))

max_age = users.groupby(['occupation'])['age'].max()

print("The maximum age for each occupation is:\n{} ".format(max_age.to_string(header = False)))
# Out:
# The minimum age for each occupation is:
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# The maximum age for each occupation is:
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# ...

# %%
# Step 7. For each combination of occupation and sex, calculate the mean age
users.groupby(['occupation', 'gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
# Step 8. For each occupation present the percentage of women and men
users.groupby('occupation')['gender'].value_counts(normalize = True)
# Out:
# occupation     gender
# administrator  M         0.544304
#                F         0.455696
# artist         M         0.535714
#                F         0.464286
# doctor         M         1.000000
# educator       M         0.726316
#                F         0.273684
# engineer       M         0.970149
#                F         0.029851
# entertainment  M         0.888889
#                F         0.111111
# executive      M         0.906250
#                F         0.093750
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         M         0.833333
#                F         0.166667
# librarian      F         0.568627
#                M         0.431373
# marketing      M         0.615385
#                F         0.384615
# none           M         0.555556
#                F         0.444444
# other          M         0.657143
#                F         0.342857
# ...

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 2 </font></h3>
# <h4><font>Euro Teams</font></h4>
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this address: https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv
#
# Step 3. Assign it to a variable called euro12
#
# Step 4. Select only the Goal column
#
# Step 5. How many teams participated in the Euro2012?
#
# Step 6. What is the number of columns in the dataset?
#
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
#
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
#
# Step 9. Calculate the mean Yellow Cards given per Team
#
# Step 10. Filter teams that scored more than 6 goals
#
# Step 11. Select the teams that start with G
#
# Step 12. Select the first 7 columns
#
# Step 13. Select all columns except the last 3
#
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
# Step 1. Import the necessary libraries
import numpy as np
import pandas as pd

# %%
# Step 2. Import the dataset from the specified address
# Step 3. Assign it to a variable called euro12
euro12 = pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12.set_index('Team', inplace=True, drop=False)

# %%
# Step 4. Select only the Goal column
euro12["Goals"]
# Out:
# Team
# Croatia                 4
# Czech Republic          4
# Denmark                 4
# England                 5
# France                  3
# Germany                10
# Greece                  5
# Italy                   6
# Netherlands             2
# Poland                  2
# Portugal                6
# Republic of Ireland     1
# Russia                  5
# Spain                  12
# Sweden                  5
# Ukraine                 2
# Name: Goals, dtype: int64

# %%
# Step 5. How many teams participated in the Euro2012?
euro12.shape[0]
# Out:
# 16

# %%
# Step 6. What is the number of columns in the dataset?
euro12.shape[1]
# Out:
# 35

# %%
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

discipline = euro12[["Yellow Cards", "Red Cards"]]
discipline
# Out:
#                      Yellow Cards  Red Cards
# Team
# Croatia                         9          0
# Czech Republic                  7          0
# Denmark                         4          0
# England                         5          0
# France                          6          0
# Germany                         4          0
# Greece                          9          1
# Italy                          16          0
# Netherlands                     5          0
# Poland                          7          1
# Portugal                       12          0
# Republic of Ireland             6          1
# Russia                          6          0
# Spain                          11          0
# Sweden                          7          0
# Ukraine                         5          0

# %%
# Step 8. Sort the teams by Red Cards, then by Yellow Cards
euro12.sort_values(by = ["Red Cards", "Yellow Cards"])
# Out:
#                                     Team  Goals  Shots on target  \
# Team
# Denmark                          Denmark      4               10
# Germany                          Germany     10               32
# England                          England      5               11
# Netherlands                  Netherlands      2               12
# Ukraine                          Ukraine      2                7
# France                            France      3               22
# Russia                            Russia      5                9
# Czech Republic            Czech Republic      4               13
# Sweden                            Sweden      5               17
# Croatia                          Croatia      4               13
# Spain                              Spain     12               42
# Portugal                        Portugal      6               22
# Italy                              Italy      6               34
# ...

# %%
# Step 9. Calculate the mean Yellow Cards given per Team
euro12["Yellow Cards"].mean()
# Out:
# 7.4375

# %%
# Step 10. Filter teams that scored more than 6 goals 
euro12.loc[euro12['Goals'] >= 6]
# Out:
#               Team  Goals  Shots on target  Shots off target  \
# Team
# Germany    Germany     10               32                32
# Italy        Italy      6               34                45
# Portugal  Portugal      6               22                42
# Spain        Spain     12               42                33
#
#          Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# Team
# Germany              47.8%            15.6%                          80
# Italy                43.0%             7.5%                         110
# Portugal             34.3%             9.3%                          82
# Spain                55.9%            16.0%                         100
#
#           Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# Team                                                         ...
# Germany              2              1                     0  ...          10
# ...

# %%
# Step 11. Select the teams that start with G
euro12[euro12["Team"].str.startswith("G")]
# Out:
#             Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# Team
# Germany  Germany     10               32                32             47.8%
# Greece    Greece      5                8                18             30.7%
#
#         % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# Team
# Germany            15.6%                          80             2
# Greece             19.2%                          32             1
#
#          Penalty goals  Penalties not scored  ...  Saves made  \
# Team                                          ...
# Germany              1                     0  ...          10
# Greece               1                     1  ...          13
#
#          Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  \
# Team
# Germany                 62.6%         63             49        12
# Greece                  65.1%         67             48        12
#
# ...

# %%
# Step 12. Select the first 7 columns 
euro12.iloc[:, 1: 7]
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
# Step 13. Select all columns except the last 3
euro12.iloc[:, 1:-3]
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia
euro12.loc[["England", "Italy", "Russia"],
            ["Shooting Accuracy"]]
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 3 </font></h3>
#
# <h4><font>Housing</font></h4>
#
# Step 1. Import the necessary libraries
#
# Step 2. Create 3 different Series, each of length 100, as follows:
#
#  - The first a random number from 1 to 4
#  - The second a random number from 1 to 3
#  - The third a random number from 10,000 to 30,000
#
# Step 3. Create a DataFrame by joining the Series by column
#
# Step 4. Change the name of the columns to bdrs, bathrs, price_sqr_meter
#
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
#
# Step 6. Oops it seems it is going only until index 99. Is this true?
#
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
# Step 1. Import the necessary libraries
import numpy as np
import pandas as pd

# %%
# Step 2. Create 3 different series, each of length 100, as specified. 
array1 = np.random.randint(1, 4, 100)
series1 = pd.Series(array1, name = "series1")

array2 = np.random.randint(1, 3, 100)
series2 = pd.Series(array2, name = "series2")

array3 = np.random.randint(10000, 30000, 100)
series3 = pd.Series(array3, name = "series3")

# %%
# Step 3. Create a DataFrame by joining the Series by column
housing = pd.concat([series1, series2, series3],axis=1)
housing
# Out:
#     series1  series2  series3
# 0         2        2    13120
# 1         2        1    20703
# 2         1        1    26353
# 3         3        2    13152
# 4         3        2    12418
# ..      ...      ...      ...
# 95        3        2    23982
# 96        3        1    16574
# 97        2        1    29505
# 98        2        2    29415
# 99        2        1    21060
#
# [100 rows x 3 columns]

# %%
# Step 4. Change the name of the columns to bdrs, bathrs, price_sqr_meter
housing = housing.rename(columns={'series1': 'bdrs', 'series2': 'bathrs', 'series3': 'price_sqr_meter'})
housing
# Out:
#     bdrs  bathrs  price_sqr_meter
# 0      2       2            13120
# 1      2       1            20703
# 2      1       1            26353
# 3      3       2            13152
# 4      3       2            12418
# ..   ...     ...              ...
# 95     3       2            23982
# 96     3       1            16574
# 97     2       1            29505
# 98     2       2            29415
# 99     2       1            21060
#
# [100 rows x 3 columns]

# %%
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = housing.stack()
bigcolumn
# Out:
# 0   bdrs                   2
#     bathrs                 2
#     price_sqr_meter    13120
# 1   bdrs                   2
#     bathrs                 1
#                        ...
# 98  bathrs                 2
#     price_sqr_meter    29415
# 99  bdrs                   2
#     bathrs                 1
#     price_sqr_meter    21060
# Length: 300, dtype: int64

# %%
# Step 6. Oops it seems it is going only until index 99. Is this true?
bigcolumn.index[-1]
# Out:
# (99, 'price_sqr_meter')

# %%
# Step 7. Reindex the DataFrame so it goes from 0 to 299
bigcolumn.reset_index()
# Out:
#      level_0          level_1      0
# 0          0             bdrs      2
# 1          0           bathrs      2
# 2          0  price_sqr_meter  13120
# 3          1             bdrs      2
# 4          1           bathrs      1
# ..       ...              ...    ...
# 295       98           bathrs      2
# 296       98  price_sqr_meter  29415
# 297       99             bdrs      2
# 298       99           bathrs      1
# 299       99  price_sqr_meter  21060
#
# [300 rows x 3 columns]

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 4 </font></h3>
#
# <h4><font>Wind Statistics</font></h4>
#
# The data have been modified to contain some missing values, identified by NaN. Using pandas should make this exercise easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using a for loop or other looping construct.
#
# The data in 'wind.data' has the following format:
#
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
#
# The first 3 columns are year, month, and day. The remaining 12 columns are average windspeeds in knots at 12 locations in Ireland on that day.
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from the attached file wind.txt
#
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index
#
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it
#
# Step 5. Set the right dates as the index. Pay attention to the data type, it should be datetime64[ns]
#
# Step 6. Compute how many values are missing for each location over the entire record. They should be ignored in all calculations below.
#
# Step 7. Compute how many non-missing values there are in total
#
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times (a single number for the entire dataset)
#
# Step 9. Create a DataFrame called day_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days (a different set of numbers for each location)
#
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day (a different set of numbers for each day)
#
# Step 11. Find the average windspeed in January for each location (treat January 1961 and January 1962 both as Janunary)
#
# Step 12. Downsample the record to a yearly frequency for each location
#
# Step 13. Downsample the record to a monthly frequency for each location
#
# Step 14. Downsample the record to a weekly frequency for each location
#
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks

# %%
# Step 1. Import the necessary libraries
import numpy as np
import pandas as pd

# %%
# Step 2. Import the dataset from the attached file wind.txt
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index

data = pd.read_csv('/Users/farahsadoon/Desktop/wind.txt', sep = ' ')
data.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
data.insert(0, "Date", data['Yr'].astype(str) +"-"+ data["Mo"].astype(str) +"-"+ data["Dy"].astype(str))
data = data.drop('Yr', axis = 1)
data = data.drop('Mo', axis = 1)
data = data.drop('Dy', axis = 1)
# data['Date'] = pd.to_datetime(data['Date'], format = '%y%m%d', errors = 'coerce')
data
# Out:
#               Date    RPT    VAL    ROS    KIL    SHA    BIR  DUB  CLA  MUL  \
# 0       61-nan-1.0  15.04    NaN    NaN   9.87  10.83  15.04  NaN  NaN  NaN
# 1       61-nan-1.0  14.71    NaN   6.50   7.67    NaN   9.67  NaN  NaN  NaN
# 2       61-nan-1.0  18.50  10.13   6.17    NaN   8.50  12.75  NaN  NaN  NaN
# 3       61-nan-1.0  10.58  11.75    NaN   2.88    NaN   5.83  NaN  NaN  NaN
# 4       61-nan-1.0  13.33    NaN    NaN    NaN  10.34    NaN  NaN  NaN  NaN
# ...            ...    ...    ...    ...    ...    ...    ...  ...  ...  ...
# 6569  78-12.0-27.0  17.62  13.21  15.59  17.21    NaN    NaN  NaN  NaN  NaN
# 6570  78-12.0-28.0   5.46   5.00    NaN  16.25  21.79    NaN  NaN  NaN  NaN
# 6571  78-12.0-29.0  14.42    NaN  19.17  16.42    NaN    NaN  NaN  NaN  NaN
# 6572  78-12.0-30.0  21.29  12.75  18.08  12.12    NaN    NaN  NaN  NaN  NaN
# 6573  78-12.0-31.0  27.29  12.08  11.63  12.08    NaN    NaN  NaN  NaN  NaN
#
#       CLO  BEL  MAL
# 0     NaN  NaN  NaN
# ...

# %%
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it
# Step 5. Set the right dates as the index. Pay attention to the data type, it should be datetime64[ns]

data.set_index('Date')
# Out:
#                 RPT    VAL    ROS    KIL    SHA    BIR  DUB  CLA  MUL  CLO  \
# Date
# 61-nan-1.0    15.04    NaN    NaN   9.87  10.83  15.04  NaN  NaN  NaN  NaN
# 61-nan-1.0    14.71    NaN   6.50   7.67    NaN   9.67  NaN  NaN  NaN  NaN
# 61-nan-1.0    18.50  10.13   6.17    NaN   8.50  12.75  NaN  NaN  NaN  NaN
# 61-nan-1.0    10.58  11.75    NaN   2.88    NaN   5.83  NaN  NaN  NaN  NaN
# 61-nan-1.0    13.33    NaN    NaN    NaN  10.34    NaN  NaN  NaN  NaN  NaN
# ...             ...    ...    ...    ...    ...    ...  ...  ...  ...  ...
# 78-12.0-27.0  17.62  13.21  15.59  17.21    NaN    NaN  NaN  NaN  NaN  NaN
# 78-12.0-28.0   5.46   5.00    NaN  16.25  21.79    NaN  NaN  NaN  NaN  NaN
# 78-12.0-29.0  14.42    NaN  19.17  16.42    NaN    NaN  NaN  NaN  NaN  NaN
# 78-12.0-30.0  21.29  12.75  18.08  12.12    NaN    NaN  NaN  NaN  NaN  NaN
# 78-12.0-31.0  27.29  12.08  11.63  12.08    NaN    NaN  NaN  NaN  NaN  NaN
#
#               BEL  MAL
# Date
# 61-nan-1.0    NaN  NaN
# ...

# %%
# Step 6. Compute how many values are missing for each location over the entire record. They should be ignored in all calculations below.
data.isnull().sum()
# Out:
# Date       0
# RPT     1625
# VAL     2432
# ROS     2152
# KIL     2331
# SHA     3204
# BIR     4065
# DUB     4416
# CLA     5590
# MUL     6574
# CLO     6574
# BEL     6574
# MAL     6574
# dtype: int64

# %%
# Step 7. Compute how many missing values there are in total
data.isnull().sum().sum()
# Out:
# 52111

# %%
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times (a single number for the entire dataset)
data.loc[:, data.columns != "Date"].mean().mean()
# Out:
# 9.749046512199465

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 5 </font></h3>
#
# Step 1. Import the necessary libraries
#
# Step 2. Import the dataset from this address: https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
#
# Step 3. Assign it to a variable called chipo
#
# Step 4. See the first 10 entries
#
# Step 5. What is the number of observations in the dataset?
#
# Step 6. What is the number of columns in the dataset?
#
# Step 7. Print the name of all the columns
#
# Step 8. How is the dataset indexed?
#
# Step 9. Which was the most-ordered item?
#
# Step 10. For the most-ordered item, how many items were ordered?
#
# Step 11. What was the most ordered item in the choice_description column?
#
# Step 12. How many items were ordered in total?
#
# Step 13. Complete the following:
#
# - Turn the item price into a float
# - Check the item price type
# - Create a lambda function and change the type of item price
# - Check the item price type
#
# Step 14. How much was the revenue for the period in the dataset?
#
# Step 15. How many orders were made in the period?
#
# Step 16. What is the average revenue amount per order?
#
# Step 17. How many different items are sold?

# %%
# Step 1. Import the necessary libraries
import numpy as np
import pandas as pd

# %%
# Step 2. Import the dataset from the specified address
# Step 3. Assign it to a variable called chipo
chipo = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Step 4. See the first 10 entries
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5. What is the number of observations in the dataset?
chipo.shape[0]
# Out:
# 4622

# %%
# Step 6. What is the number of columns in the dataset?
chipo.shape[1]
# Out:
# 5

# %%
# Step 7. Print the name of all the columns
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Step 8. How is the dataset indexed?
chipo.index

# The dataset is indexed by the number of items ordered for each order_id
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Step 9. Which was the most-ordered item?
chipo.item_name.mode()
# Out:
# 0    Chicken Bowl
# Name: item_name, dtype: object

# %%
# Step 10. For the most-ordered item, how many items were ordered?
chipo['item_name'].value_counts().nlargest(1)
# Out:
# item_name
# Chicken Bowl    726
# Name: count, dtype: int64

# %%
# Step 11. What was the most ordered item in the choice_description column?
chipo.choice_description.mode()
# Out:
# 0    [Diet Coke]
# Name: choice_description, dtype: object

# %%
# Step 12. How many items were ordered in total?
chipo.item_name.value_counts().sum()
# Out:
# 4622

# %%
# Step 13. Complete the following: 
# - Turn the item price into a float
# - Check the item price type
chipo['item_price'] = chipo['item_price'].str.replace('$', '')
chipo['item_price'] = chipo.item_price.astype('float64')
chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
# Step 13. Complete the following: 
# - Create a lambda function and change the type of item price
# - Check the item price type

chipo['item_price'] = chipo['item_price'].apply(lambda x: np.int16(x))
chipo.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price             int16
# dtype: object

# %%
# Step 14. How much was the revenue for the period in the dataset?
revenue = chipo.item_price.sum()
print("The total revenue for the period in the dataset was: ${}".format(revenue))
# Out:
# The total revenue for the period in the dataset was: $32052

# %%
# Step 15. How many orders were made in the period?
chipo.order_id.max()
# Out:
# 1834

# %%
# Step 16. What is the average revenue amount per order?
chipo.groupby(['order_id'])['item_price'].mean().mean()
# Out:
# 7.2991676332402236

# %%
# Step 17. How many different items are sold?
chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 6 </font></h3>
#
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend. Don't forget to label your axes!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

marriage_divorce = pd.read_csv('/Users/farahsadoon/Desktop/us-marriages-divorces-1867-2014.csv', header = 0)

marriage_divorce.plot("Year", y = ['Marriages_per_1000', 'Divorces_per_1000'])
pp.title('Marriages and Divorces per Capita in the U.S. 1867-2014')
pp.ylabel('Number of Marriages or Divorces per Capita')
# Out:
# Text(0, 0.5, 'Number of Marriages or Divorces per Capita')

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 7 </font></h3>
#
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000. Don't forget to label your axes!

# %%
data = {"Year": [1900, 1950, 2000], "Marriages per Capita": [9.3, 11, 8.2],
       "Divorces per Capita": [0.7, 2.5, 3.3]}
marriage_divorce = pd.DataFrame(data)
marriage_divorce.set_index("Year")

ax = marriage_divorce.plot.bar(x = "Year")
ax.set_ylabel("Marriages or Divorces per Capita")
ax.set_title("Number of Marriages and Divorces per Capita in the U.S. 1900, 1950, 2000")

pp.show()

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 8 </font></h3>
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name. Don't forget to label your axes!

# %%
actor_kills = pd.read_csv('/Users/farahsadoon/Desktop/actor_kill_counts.csv', header = 0)

actors = actor_kills["Actor"]
kills = actor_kills["Count"]
fig, ax = pp.subplots()
y_pos = np.arange(len(actors))

ax.barh(y_pos, sorted(kills))
ax.set_yticks(y_pos, labels = actors)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Kill Counts')
ax.set_title('Deadliest Actors in Hollywood')
# Out:
# Text(0.5, 1.0, 'Deadliest Actors in Hollywood')

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 9 </font></h3>
#
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
#
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
roman_emps = pd.read_csv('/Users/farahsadoon/Desktop/roman-emperor-reigns.csv', header = 0)
labels = roman_emps["Emperor"]
sizes = roman_emps['Cause_of_Death'].value_counts()

pp.pie(roman_emps['Cause_of_Death'].value_counts(), labels = roman_emps['Cause_of_Death'].value_counts().index, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9b34202c20>,
# ...
#  [Text(0.5790753482603685, 0.9352388684379692, 'Assassinated'),
#   Text(-1.025719479700726, 0.39736576219205416, 'Natural causes'),
#   Text(-0.8129097548643817, -0.7410652673323255, 'Possibly assassinated'),
#   Text(-0.10149511246469993, -1.0953076016105148, 'Killed in battle'),
#   Text(0.5352650097816886, -0.9609845832808188, 'Suicide'),
#   Text(0.9074972879645549, -0.6216499596533229, 'Illness'),
#   Text(1.0707818897912493, -0.25184547741637286, 'Executed'),
#   Text(1.0988262785166438, -0.050801669670033, 'Died in captivity')],
#  [Text(0.31585928086929194, 0.5101302918752558, '32.4%'),
#   Text(-0.5594833525640323, 0.2167449611956659, '23.5%'),
#   Text(-0.44340532083511724, -0.4042174185449047, '11.8%'),
#   Text(-0.05536097043529086, -0.5974405099693716, '11.8%'),
#   Text(0.2919627326081937, -0.5241734090622647, '7.4%'),
#   Text(0.494998520707939, -0.3390817961745397, '7.4%'),
# ...

# %% [markdown]
# <h3><font color='#004b87'>QUESTION 10 </font></h3>
#
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009. Don't forget to label your axes!
#
# Colour each dot according to its year.

# %%
rev_docs = pd.read_csv('/Users/farahsadoon/Desktop/arcade-revenue-vs-cs-doctorates.csv', header = 0)
colors = {2000:'C0', 2001:'C1', 2002:'C2', 2003:'C3', 2004:'C4', 2005:'C5', 2006:'C6', 2007:'C7', 2008:'C8', 2009:'C9'}
fig, ax = pp.subplots()

for i in range(len(rev_docs['Year'])):
    ax.scatter(rev_docs['Total Arcade Revenue (billions)'][i], 
               rev_docs['Computer Science Doctorates Awarded (US)'][i],
               color=colors[rev_docs['Year'][i]])

ax.set_title('Total Revenue Earned by Arcades by Number of Computer Science PhDs (U.S.)')
ax.set_xlabel('Total Arcade Revenue (billions)')
ax.set_ylabel('Number of Computer Science PhDs Awarded (US)')
# Out:
# Text(0, 0.5, 'Number of Computer Science PhDs Awarded (US)')
